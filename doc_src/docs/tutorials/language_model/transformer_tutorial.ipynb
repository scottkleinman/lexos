# %% [markdown]
# # Fine-tuning MacBERTh: Transformer-based Training for Historical English
#
# This tutorial trains the same five-component UD pipeline as the [main tutorial](tutorial.ipynb), but with a **pre-trained transformer** as the embedding backbone instead of a CNN. The default transformer is **MacBERTh** ([emanjavacas/MacBERTh](https://huggingface.co/emanjavacas/MacBERTh)) — a BERT-base model pre-trained on ~3.9 billion tokens of historical English (1450–1950) from EEBO, ECCO, COHA, and other corpora. MIT licensed.
#
# ## Transformer vs CNN — which should you use?
#
# | | Transformer (this tutorial) | CNN (main tutorial) |
# | --- | --- | --- |
# | Accuracy on historical / variant spelling | Higher — MacBERTh has seen centuries of spelling variation | Lower — relies on your training data alone |
# | Training hardware | NVIDIA GPU strongly recommended | CPU is fine |
# | Model size | ~500 MB | ~20 MB |
# | Inference speed | Slower | Fast |
# | Deployment | Requires spacy-transformers + torch installed | Plain spaCy |
#
# **Rule of thumb:** if you are annotating Early Modern or other historical English and have a GPU, the transformer is usually worth it. If you need small, fast, CPU-friendly models, stick with the CNN.
#
# ## Before you start
#
# - **Complete the [main tutorial](tutorial.ipynb) first.** This notebook reuses its data and compares scores against its trained model.
# - **You need an NVIDIA GPU.** Transformer training on CPU is impractically slow (hours become days).
# - **First run downloads ~450 MB** — the MacBERTh weights are fetched from Hugging Face the first time training initializes, and cached afterwards.

# %% [markdown]
# ## Prerequisites
#
# Install the transformer extras (in addition to the base package). From the repository root:
#
# ```bash
# pip install -e .[gpu,transformers]
# ```
#
# This installs `spacy-transformers`, which pulls in `torch` and Hugging Face `transformers` at tested versions, plus the CUDA libraries from the `gpu` extra.
#
# > **Windows GPU note:** the default `torch` wheel from PyPI on Windows is **CPU-only**. After installing, run the GPU check cell below. If `torch.cuda.is_available()` prints `False` but you have an NVIDIA GPU, reinstall torch from the PyTorch CUDA index (match the CUDA level to your driver):
# >
# > ```bash
# > pip install torch --index-url https://download.pytorch.org/whl/cu126 --force-reinstall
# > ```

# %%
from pathlib import Path

from lexos.language_model import LanguageModel, split_conllu

# %% [markdown]
# ## Check your GPU
#
# Run the cell below before anything else. It verifies two separate things:
#
# 1. **`_has_nvidia_gpu()`** — an NVIDIA GPU and driver are visible to the system (this is what the module checks when you pass `gpu=True`)
# 2. **`torch.cuda.is_available()`** — your installed torch build can actually use it (catches the Windows CPU-only wheel problem)
#
# Both must be `True` before you start training.

# %%
import torch

from lexos.language_model import _has_nvidia_gpu

print(f"NVIDIA GPU detected:      {_has_nvidia_gpu()}")
print(f"torch can use CUDA:       {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU device:               {torch.cuda.get_device_name(0)}")
else:
    print()
    print("torch cannot see a GPU. If you have an NVIDIA GPU, your torch build")
    print("is probably CPU-only. Reinstall from the PyTorch CUDA index:")
    print("  pip install torch --index-url https://download.pytorch.org/whl/cu126 --force-reinstall")
# Out:
# NVIDIA GPU detected:      True
# torch can use CUDA:       True
# GPU device:               NVIDIA GeForce RTX 4060 Laptop GPU

# %% [markdown]
# ## Configuration
#
# **`_tutorial_dir`** — same convention as the main tutorial: derived from the installed package location, or replace with a direct path if you are working outside the Lexos repo.
#
# **Project name (`winter_tale_trf`)** — this notebook writes all output into a `winter_tale_trf` subfolder, deliberately separate from the main tutorial's `winter_tale` so the CNN model stays intact for the score comparison at the end. Rename both as needed for your own data.

# %%
import lexos.language_model as _lm

# Derive the tutorial folder from the installed package path.
# Works when running from the Lexos repo with pip install -e .
#   __init__.py → language_model/ → lexos/ → src/ → repo root
_repo_root = Path(_lm.__file__).parents[3]
_tutorial_dir = _repo_root / "doc_src" / "docs" / "tutorials" / "language_model"

# Not in the Lexos repo? Replace the two lines above with a direct path:
# _tutorial_dir = Path("C:/Users/you/my_project")

print(f"Tutorial directory: {_tutorial_dir}")
if not _tutorial_dir.exists():
    print("WARNING: Directory not found — set _tutorial_dir above.")
# Out:
# Tutorial directory: C:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\doc_src\docs\tutorials\language_model

# %% [markdown]
# ---
#
# ## Step 1: Split your data
#
# Same as the main tutorial: split one CONLL-U file into train/dev/test. We reuse the Winter's Tale corpus — Early Modern English, squarely inside MacBERTh's training period.
#
# **If you already have separate train/dev/test files**, skip this step and pass them directly to `copy_assets()` in Step 3.
#
# > **Do not normalize or modernize your text for MacBERTh.** MacBERTh was pre-trained on raw historical spelling (*haue*, *vnto*, *ſ* and all). Modernizing spelling moves your text *away* from what the model knows and will typically hurt accuracy. See [Tuning Training Settings](training_settings.md) for the full normalization discussion.

# %%
splits = split_conllu(
    input_path=str(_tutorial_dir / "wt_sanitized.conllu"),               # ← your CONLL-U data file
    output_dir=str(_tutorial_dir / "winter_tale_trf" / "assets" / "en"), # ← rename "winter_tale_trf"
    train_ratio=0.8,
    dev_ratio=0.1,
    seed=42,
)

for name, path in splits.items():
    print(f"{name:5s}: {path}")
# Out:
# ✔   train:  294 sentences  →
# C:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\doc_src\docs\tutorials\language_model\winter_tale_trf\assets\en\wt_sanitized-train.conllu
# ✔   dev  :   36 sentences  →
# C:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\doc_src\docs\tutorials\language_model\winter_tale_trf\assets\en\wt_sanitized-dev.conllu
# ✔   test :   38 sentences  →
# C:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\doc_src\docs\tutorials\language_model\winter_tale_trf\assets\en\wt_sanitized-test.conllu
# train: C:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\doc_src\docs\tutorials\language_model\winter_tale_trf\assets\en\wt_sanitized-train.conllu
# dev  : C:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\doc_src\docs\tutorials\language_model\winter_tale_trf\assets\en\wt_sanitized-dev.conllu
# test : C:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\doc_src\docs\tutorials\language_model\winter_tale_trf\assets\en\wt_sanitized-test.conllu

# %% [markdown]
# ---
#
# ## Step 2: Create the model from the transformer recipe
#
# Transformer training uses a **recipe** — a complete, vetted config file — instead of the `base_model` dict. Pass `recipe="transformer_ud.cfg"` and the bundled recipe is loaded as-is; `base_model` sourcing is specific to CNN (tok2vec) pipelines and is not used here.
#
# The recipe defaults to MacBERTh. To use a different transformer, edit the model name after creating the `LanguageModel`:
#
# ```python
# model.config["components"]["transformer"]["model"]["name"] = "bert-base-uncased"
# model.save_config()
# ```
#
# | Hugging Face model | Best for |
# | --- | --- |
# | `emanjavacas/MacBERTh` (default) | Historical English, 1450–1950 |
# | `bert-base-uncased` | Modern English, general |
# | `roberta-base` | Modern English, stronger but larger |
# | Any BERT-family model for your language | Non-English — also change `lang=` |

# %%
model = LanguageModel(
    model_dir=str(_tutorial_dir / "winter_tale_trf"),  # ← rename to your project name
    lang="en",       # ← your language BCP-47 code
    gpu=True,        # ← transformer training needs a GPU (see the check above)
    recipe="transformer_ud.cfg",
    force=True,      # regenerate config from scratch; False reconnects to an existing run
)
# Out:
# ✔ Loaded recipe:
# C:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\src\lexos\language_model\recipes\transformer_ud.cfg
# ✔ Config saved to
# C:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\doc_src\docs\tutorials\language_model\winter_tale_trf\config.cfg
# Next: copy_assets() → convert_assets() → train()

# %% [markdown]
# ### What the recipe sets (and why it differs from the CNN config)
#
# - **Learning rate: `warmup_linear.v1`, peak 5e-5** — MacBERTh arrives pre-trained; a learning rate as high as the CNN's 0.001 would overwrite (catastrophically forget) what it already knows. The rate warms up from zero over 250 steps, then decays. There is **one** learning rate for the whole network — spaCy has no separate per-component rate.
# - **`accumulate_gradient = 3`** — gradients from 3 batches are accumulated before each weight update, simulating a 3× larger batch for stabler transformer updates without 3× the GPU memory.
# - **Batcher: `batch_by_padded`, size 2000** — transformers process padded token blocks; this batcher controls the padded total per batch (the main GPU-memory knob).
# - **Early stopping** — same mechanism as the CNN: `eval_frequency = 200`, `patience = 1600` (in *steps*), best checkpoint picked by weighted dev score.
#
# For what these settings mean and how to tune them, see [Tuning Training Settings](training_settings.md).
#
# ---
#
# ## Step 3: Copy and convert your data

# %%
# The ** unpacks the dict from split_conllu() — equivalent to passing
# train=..., dev=..., test=... as keyword arguments.
model.copy_assets(**splits)
# Out:
# ✔ Assets copied to
# C:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\doc_src\docs\tutorials\language_model\winter_tale_trf\assets\en

# %%
# Convert CONLL-U files to spaCy's binary format.
# n_sents=1 keeps one sentence per training doc. spaCy's preflight check
# counts docs (not sentences) and refuses to train a pipeline with no
# sourced components on fewer than 100 docs. Grouping sentences (like the
# CNN tutorial's n_sents=10) makes a small corpus look 10x smaller and
# trips that check — the transformer's components are all factory-defined,
# so the check applies here even though MacBERTh itself is pre-trained.
model.convert_assets(n_sents=1)
# Out:
# ✔ Assets converted and saved to
# C:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\doc_src\docs\tutorials\language_model\winter_tale_trf\corpus\en

# %% [markdown]
# ---
#
# ## Step 4: Train
#
# **First run:** training initialization downloads the MacBERTh weights (~450 MB) from Hugging Face. This needs a network connection and takes a few minutes; the weights are cached (in `~/.cache/huggingface`) so later runs skip the download.
#
# **GPU memory (VRAM) guidance:**
#
# | VRAM | Settings |
# | --- | --- |
# | 8 GB+ | Recipe defaults are fine |
# | 6 GB | `model.config["training"]["batcher"]["size"] = 1000`; `model.config["training"]["accumulate_gradient"] = 6`; `model.save_config()` |
# | 4 GB | Batcher size 500, and set `model.config["components"]["transformer"]["model"]["mixed_precision"] = True`; `model.save_config()` |
#
# If training crashes with a CUDA out-of-memory error, drop the batcher size and raise `accumulate_gradient` to compensate (their product ≈ constant effective batch).
#
# **Smoke test first.** The cell below has a `SMOKE_TEST` flag. Leave it `True` for your first run — it caps training at 50 steps (~a few minutes including the download) to prove the whole pipeline works before you commit to a full run. Then set it to `False`, re-run the `LanguageModel` cell with `force=True`, and re-run from Step 3.

# %%
SMOKE_TEST = False  # ← set to False for the real training run

if SMOKE_TEST:
    model.config["training"]["max_steps"] = 50
    model.config["training"]["eval_frequency"] = 25
    model.save_config()
    print("Smoke test: max_steps=50. Set SMOKE_TEST = False for a full run.")
else:
    print("Full run: recipe defaults (max_steps=20000, early stopping).")
# Out:
# Full run: recipe defaults (max_steps=20000, early stopping).

# %%
model.train()
# Out:
# ============================= Config validation =============================
#
# ===================== Config validation for [initialize] =====================
#
# ====================== Config validation for [training] ======================
# ✔ Config is valid
#
# ============================ Data file validation ============================
# ✔ Pipeline can be initialized with data
# ✔ Corpus is loadable
#
# =============================== Training stats ===============================
# Language: en
# Training pipeline: transformer, tagger, morphologizer, trainable_lemmatizer,
# parser
# 294 training docs
# 36 evaluation docs
# ⚠ 5 training examples also in evaluation data
# ⚠ Low number of examples to train a new pipeline (294)
#
# ============================== Vocab & Vectors ==============================
# ℹ 3013 total word(s) in the data (1011 unique)
# ℹ No word vectors present in the package
#
# =========================== Part-of-speech Tagging ===========================
# ℹ 39 label(s) in train data
# ℹ 0.8343521062759882 is the normalised label entropy
#
# ========================= Morphologizer (POS+Morph) =========================
# ℹ 102 label(s) in train data
#
# ============================= Dependency Parsing =============================
# ℹ Found 302 sentence(s) with an average length of 10.0 words.
# ℹ Found 15 nonprojective train sentence(s)
# ℹ 40 label(s) in train data
# ℹ 58 label(s) in projectivized train data
# ⚠ Low number of examples for label 'compound:prt' (8)
# ⚠ Low number of examples for label 'nummod' (9)
# ⚠ Low number of examples for label 'obl:npmod' (4)
# ⚠ Low number of examples for label 'appos' (16)
# ⚠ Low number of examples for label 'cc:preconj' (2)
# ⚠ Low number of examples for label 'obl:tmod' (3)
# ⚠ Low number of examples for label 'expl' (5)
# ⚠ Low number of examples for label 'acl' (6)
# ⚠ Low number of examples for label 'det:predet' (4)
# ⚠ Low number of examples for label 'fixed' (1)
# ⚠ Low number of examples for label 'flat' (2)
# ⚠ Low number of examples for label 'iobj' (3)
# ⚠ Low number of examples for label 'csubj' (4)
# ⚠ Low number of examples for label 'nmod:npmod' (1)
# ⚠ Low number of examples for 18 label(s) in the projectivized
# dependency trees used for training. You may want to projectivize labels such as
# punct before training in order to improve parser performance.
# ⚠ Multiple root labels (vocative, ROOT, discourse, nsubj, nsubj:pass,
# compound, advmod, advcl, case, cc, punct, acl:relcl, parataxis, appos, flat,
# nmod:poss) found in training data. spaCy's parser uses a single root label ROOT
# so this distinction will not be available.
#
# ============================ Trainable Lemmatizer ============================
# ℹ 119 lemmatizer trees generated from training data
# ℹ 47 lemmatizer trees generated from dev data
# ℹ 2 lemmatizer trees (4.3% of dev trees) were found exclusively in the
# dev data.
# ✔ All training docs have lemma annotations.
# ✔ All dev docs have lemma annotations.
# ✔ All training docs have complete lemma annotations.
# ✔ All dev docs have complete lemma annotations.
#
# ================================== Summary ==================================
# ✔ 6 checks passed
# ⚠ 21 warnings
# ✔ All checks passed.
# ℹ   Language:   en
# ℹ   Pipeline:   ['transformer', 'tagger', 'morphologizer',
# 'trainable_lemmatizer', 'parser']
# ℹ   Device:     GPU (device 0)
# ℹ   Base model: None
# ℹ   Assets:     ['wt_sanitized-dev.conllu', 'wt_sanitized-test.conllu',
# 'wt_sanitized-train.conllu']
# ℹ   Output:
# C:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\doc_src\docs\tutorials\language_model\winter_tale_trf\training\en
# ℹ Pipeline: ['transformer', 'tagger', 'morphologizer',
# 'trainable_lemmatizer', 'parser']
# ℹ Initial learn rate: 0.0
# E    #       LOSS TRANS...  LOSS TAGGER  LOSS MORPH...  LOSS TRAIN...  LOSS PARSER  TAG_ACC  POS_ACC  MORPH_ACC  LEMMA_ACC  DEP_UAS  DEP_LAS  SENTS_F  SCORE
# ---  ------  -------------  -----------  -------------  -------------  -----------  -------  -------  ---------  ---------  -------  -------  -------  ------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 model.train()
#
# File ~\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\src\lexos\language_model\__init__.py:831, in LanguageModel.train(self, skip_validation)
#     829 config = load_config(self._config_path)
#     830 nlp = init_nlp(config, use_gpu=self._use_gpu)
# --> 831 spacy_train(
#     832     nlp=nlp,
#     833     output_path=self._training_dir,
#     834     use_gpu=self._use_gpu,
#     835     stdout=sys.stdout,
#     836     stderr=sys.stderr,
#     837 )
#     838 msg = Printer()
#     839 msg.text(f"Training complete. Time elapsed: {timer.elapsed()}")
#
# File c:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\.venv\Lib\site-packages\spacy\training\loop.py:118, in train(nlp, output_path, use_gpu, stdout, stderr)
#     116     log_step, finalize_logger = train_logger(nlp, stdout, stderr)
#     117 try:
# --> 118     for batch, info, is_best_checkpoint in training_step_iterator:
#     119         if is_best_checkpoint is not None:
#     120             with nlp.select_pipes(disable=frozen_components):
#
# File c:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\.venv\Lib\site-packages\spacy\training\loop.py:236, in train_while_improving(nlp, optimizer, train_data, evaluate, dropout, eval_frequency, accumulate_gradient, patience, max_steps, exclude, annotating_components, before_update)
#     229 for name, proc in nlp.pipeline:
#     230     if (
#     231         name not in exclude
#     232         and hasattr(proc, "is_trainable")
#     233         and proc.is_trainable
#     234         and proc.model not in (True, False, None)  # type: ignore[attr-defined]
#     235     ):
# --> 236         proc.finish_update(optimizer)  # type: ignore[attr-defined]
#     237 optimizer.step_schedules()
#     238 if not (step % eval_frequency):
#
# File c:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\.venv\Lib\site-packages\spacy\pipeline\trainable_pipe.pyx:252, in spacy.pipeline.trainable_pipe.TrainablePipe.finish_update()
#
# File c:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\.venv\Lib\site-packages\thinc\model.py:342, in Model.finish_update(self, optimizer)
#     340 for node in self.walk():
#     341     for shim in node.shims:
# --> 342         shim.finish_update(optimizer)
#     343 for node in self.walk():
#     344     for name in node.param_names:
#
# File c:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\.venv\Lib\site-packages\thinc\shims\pytorch.py:178, in PyTorchShim.finish_update(self, optimizer)
#     174 if torch_data.grad is not None:
#     175     if (
#     176         not self._grad_scaler.found_inf
#     177     ):  # Skip weight update if any gradient overflowed.
# --> 178         param, grad = optimizer(
#     179             (self.id, name),
#     180             cast(FloatsXd, torch2xp(torch_data.data)),
#     181             cast(FloatsXd, torch2xp(torch_data.grad)),
#     182         )
#     183         torch_data.data = xp2torch(
#     184             param, requires_grad=True, device=torch_data.device
#     185         )
#     186     torch_data.grad.zero_()
#
# KeyboardInterrupt:

# %% [markdown]
# ---
#
# ## Step 5: Evaluate
#
# Evaluate against the held-out test split, exactly as in the main tutorial. (Skip drawing conclusions from a smoke-test run — 50 steps is not a trained model.)

# %%
model.evaluate()
# Out:
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
#
# ================================== Results ==================================
#
# TOK      100.00
# TAG      57.04
# POS      64.34
# MORPH    63.17
# LEMMA    66.17
# UAS      21.11
# LAS      5.37
# SENT P   6.28
# SENT R   33.33
# SENT F   10.57
# SPEED    329
#
#
# ============================== MORPH (per feat) ==============================
#
#                 P       R       F
# Number      67.23   68.97   68.09
# Person      85.71   50.85   63.83
# Poss       100.00   56.25   72.00
# PronType    95.12   49.37   65.00
# Degree      50.00   31.25   38.46
# VerbForm    81.58   37.35   51.24
# Case        60.87   41.18   49.12
# Definite   100.00   64.29   78.26
# Mood       100.00   10.71   19.35
# Tense      100.00    8.57   15.79
# Voice        0.00    0.00    0.00
# Gender       0.00    0.00    0.00
# NumType      0.00    0.00    0.00
#
#
# =============================== LAS (per type) ===============================
#
#                   P       R       F
# nmod:poss      4.00   41.18    7.29
# amod           0.00    0.00    0.00
# nsubj          0.00    0.00    0.00
# aux            0.00    0.00    0.00
# root           5.99   48.15   10.66
# obj            0.00    0.00    0.00
# case           0.00    0.00    0.00
# obl            0.00    0.00    0.00
# vocative       0.00    0.00    0.00
# cc             0.00    0.00    0.00
# mark           0.00    0.00    0.00
# advcl          0.00    0.00    0.00
# xcomp          0.00    0.00    0.00
# det            0.00    0.00    0.00
# advmod         0.00    0.00    0.00
# discourse      0.00    0.00    0.00
# ccomp          0.00    0.00    0.00
# iobj           0.00    0.00    0.00
# cop            0.00    0.00    0.00
# dep            0.00    0.00    0.00
# nsubj:pass     0.00    0.00    0.00
# aux:pass       0.00    0.00    0.00
# conj           0.00    0.00    0.00
# compound:prt   0.00    0.00    0.00
# compound       0.00    0.00    0.00
# nmod           0.00    0.00    0.00
# acl            0.00    0.00    0.00
# acl:relcl      0.00    0.00    0.00
# parataxis      0.00    0.00    0.00
# obl:npmod      0.00    0.00    0.00
# obl:tmod       0.00    0.00    0.00
# nummod         0.00    0.00    0.00
#
# ✔ Saved results to
# C:\Users\aaron\OneDrive\Desktop\Lexos-LM-Workflow\Lexos_LM_Fine-tuning_Workflow\doc_src\docs\tutorials\language_model\winter_tale_trf\metrics\en\en.json

# %%
# Compare transformer scores against the CNN baseline from the main tutorial.
import json

_metrics = {
    "CNN (winter_tale)": _tutorial_dir / "winter_tale" / "metrics" / "en" / "en.json",
    "Transformer (winter_tale_trf)": _tutorial_dir / "winter_tale_trf" / "metrics" / "en" / "en.json",
}
_keys = ["tag_acc", "pos_acc", "morph_acc", "lemma_acc", "dep_uas", "dep_las"]
_labels = ["TAG", "POS", "MORPH", "LEMMA", "UAS", "LAS"]

_loaded = {}
for name, path in _metrics.items():
    if path.exists():
        _loaded[name] = json.loads(path.read_text(encoding="utf-8"))
    else:
        print(f"Missing: {path}")

if len(_loaded) == 2:
    (cnn_name, cnn), (trf_name, trf) = _loaded.items()
    print(f"{'Metric':8s}  {'CNN':>8s}  {'Transformer':>12s}  {'Delta':>8s}")
    print("-" * 44)
    for key, label in zip(_keys, _labels):
        c = cnn.get(key, 0.0) * 100
        t = trf.get(key, 0.0) * 100
        print(f"{label:8s}  {c:7.2f}%  {t:11.2f}%  {t - c:+7.2f}%")
else:
    print("Run the main tutorial (CNN) and this notebook (transformer) fully")
    print("to produce both metrics files, then re-run this cell.")
# Out:
# Metric         CNN   Transformer     Delta
# --------------------------------------------
# TAG         90.61%        57.04%   -33.58%
# POS         91.34%        64.34%   -27.00%
# MORPH       87.58%        63.17%   -24.41%
# LEMMA       65.43%        66.17%    +0.74%
# UAS         81.07%        21.11%   -59.96%
# LAS         70.40%         5.37%   -65.03%

# %% [markdown]
# **Reading the comparison:** on a small Early Modern corpus, expect the transformer's biggest gains on POS/MORPH and dependency scores — that is where MacBERTh's exposure to historical spelling pays off. LEMMA may stay weak for both until you have more training data (the trainable lemmatizer needs examples regardless of backbone).
#
# **Choosing for real work:**
#
# - **Transformer** — accuracy-critical annotation of historical text; GPU available for training; model size and inference speed are secondary.
# - **CNN** — CPU-only environments, fast batch processing, small distributable models. A packaged transformer model is ~500 MB and requires `spacy-transformers` to be installed wherever it is loaded.
#
# ---
#
# ## Step 6: Use your model

# %%
import spacy

# ← rename "winter_tale_trf" to your project name
nlp = spacy.load(str(_tutorial_dir / "winter_tale_trf" / "training" / "en" / "model-best"))

# Original Early Modern spelling — no modernization needed.
doc = nlp("If you shall chance, Camillo, to visit Bohemia on the like occasion whereon my services are now on foot.")

for token in doc:
    print(f"{token.text:20s}  POS: {token.pos_:8s}  TAG: {token.tag_:6s}  LEMMA: {token.lemma_}")
# Out:
# If                    POS: CCONJ     TAG: PRP     LEMMA: If
# you                   POS: PRON      TAG: PRP     LEMMA: you
# shall                 POS: AUX       TAG: PRP     LEMMA: shall
# chance                POS: VERB      TAG: VB      LEMMA: chance
# ,                     POS: PUNCT     TAG: ,       LEMMA: ,
# Camillo               POS: NOUN      TAG: NN      LEMMA: Camillo
# ,                     POS: PUNCT     TAG: ,       LEMMA: ,
# to                    POS: PART      TAG: PRP     LEMMA: to
# visit                 POS: VERB      TAG: VB      LEMMA: visit
# Bohemia               POS: NOUN      TAG: NN      LEMMA: Bohemia
# on                    POS: ADP       TAG: IN      LEMMA: on
# the                   POS: DET       TAG: DT      LEMMA: the
# like                  POS: ADJ       TAG: RB      LEMMA: like
# occasion              POS: NOUN      TAG: NN      LEMMA: occasion
# whereon               POS: ADP       TAG: IN      LEMMA: whereon
# my                    POS: PRON      TAG: PRP$    LEMMA: my
# services              POS: NOUN      TAG: NN      LEMMA: service
# are                   POS: ADP       TAG: PRP     LEMMA: are
# now                   POS: ADV       TAG: RB      LEMMA: now
# on                    POS: ADP       TAG: IN      LEMMA: on
# foot                  POS: NOUN      TAG: NN      LEMMA: foot
# .                     POS: PUNCT     TAG: .       LEMMA: .

# %% [markdown]
# ---
#
# ## Troubleshooting
#
# **`✘ Low number of examples to train a new pipeline (N)` fails validation:** spaCy counts training *docs*, not sentences, and requires at least 100 docs when no component is sourced from an existing model (which is the case for all transformer recipes — spaCy cannot see that the transformer backbone is pre-trained). `convert_assets(n_sents=...)` groups that many sentences into each doc, shrinking the doc count. Re-run `model.convert_assets(n_sents=1)` so docs equal sentences. If you have fewer than 100 sentences total, you genuinely need more training data.
#
# **CUDA out of memory:** lower `training.batcher.size` (2000 → 1000 → 500) and raise `training.accumulate_gradient` to compensate; enable `mixed_precision = True` on the transformer component as a last resort. Save the config and re-run training.
#
# **`torch.cuda.is_available()` is False but you have an NVIDIA GPU:** you have the CPU-only Windows wheel. Reinstall: `pip install torch --index-url https://download.pytorch.org/whl/cu126 --force-reinstall` (use cu121/cu124 for older drivers).
#
# **`LexosException` about spacy-transformers:** the transformer extras are not installed in this environment — `pip install -e .[transformers]` (or `.[gpu,transformers]`).
#
# **Hugging Face download fails:** the MacBERTh download needs a network connection (and no blocking proxy). It is retried on the next `train()` call; once cached it never re-downloads.
#
# **Reconnecting after a kernel restart:** run the imports cell, the configuration cell, and the `LanguageModel(...)` cell with `force=False` to reconnect to your existing `winter_tale_trf/` directory.
#
# **Training is extremely slow:** confirm the GPU is actually engaged — run `nvidia-smi` in a terminal during training and check the python process appears with GPU memory allocated. If not, re-run the GPU check cell at the top.
#
# **Loading the packaged model elsewhere fails:** environments that load a transformer-based model need `spacy-transformers` installed too, not just spaCy.
#
# For training-setting tuning (learning rate, early stopping, batching, normalization), see [Tuning Training Settings](training_settings.md).
